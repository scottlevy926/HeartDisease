# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
DATA_DIR = '../MIS 776'
FILE_NAME = 'Heart 2.csv'
data_path = os.path.join(DATA_DIR, FILE_NAME)
datHeart = pd.read_csv(data_path)

# %%
datHeart.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   54   M           ASY        200          198          0     Normal    142
# 1   64   F           ASY        200            0          0     Normal    140
# 2   61   M           NAP        200            0          1         ST     70
# 3   56   F           ASY        200          288          1        LVH    133
# 4   54   M           ATA        192          283          0        LVH    195
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              Y      2.0     Flat             1
# 1              Y      1.0     Flat             1
# 2              N      0.0     Flat             1
# 3              Y      4.0     Down             1
# 4              N      0.0       Up             1

# %%
datHeart.mean()
# Out:
# Age              53.510893
# RestingBP       132.396514
# Cholesterol     198.799564
# FastingBS         0.233115
# MaxHR           136.809368
# Oldpeak           0.887364
# HeartDisease      0.553377
# dtype: float64

# %%
numeric_features = ['Age','RestingBP','Cholesterol','FastingBS','MaxHR','Oldpeak','HeartDisease']

# %%
datHeart[numeric_features]

# %%
sns.pairplot(datHeart[numeric_features], plot_kws={"s": 3});

# %%
plt.hist(datHeart['Age'])
# Out:
# (array([ 12.,  37.,  86., 104., 148., 201., 175., 101.,  39.,  15.]),
#  array([28. , 32.9, 37.8, 42.7, 47.6, 52.5, 57.4, 62.3, 67.2, 72.1, 77. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(datHeart['RestingBP'])
# Out:
# (array([  1.,   0.,   0.,   0.,  12., 148., 430., 234.,  73.,  20.]),
#  array([  0.,  20.,  40.,  60.,  80., 100., 120., 140., 160., 180., 200.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(datHeart['Cholesterol'])
# Out:
# (array([172.,   6.,  70., 319., 248.,  81.,  14.,   3.,   3.,   2.]),
#  array([  0. ,  60.3, 120.6, 180.9, 241.2, 301.5, 361.8, 422.1, 482.4,
#         542.7, 603. ]),
#  <a list of 10 Patch objects>)
